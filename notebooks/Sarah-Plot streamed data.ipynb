# %%
import pandas as pd

# %%
df = pd.read_csv('../Thalassa_Regime_Classifier/predicted_values.csv')
df.head()
# Out:
#    Unnamed: 0          primary_key        bp1           bp2           bp3  \
# 0           0  2022-05-27 11:54:26  28897.080  28896.950000  28896.880000
# 1           1  2022-05-27 11:54:27  28897.080  28896.950000  28896.910000
# 2           2  2022-05-27 11:54:28  28897.080  28896.986667  28896.923333
# 3           3  2022-05-27 11:54:29  28897.080  28897.005000  28896.930000
# 4           4  2022-05-27 11:54:30  28897.512  28897.432000  28897.104000
#
#         bp4           bp5       bs1       bs2       bs3  ...        ap1  \
# 0  28896.43  28895.690000  2.346410  0.011880  0.026910  ...  28897.090
# 1  28896.43  28895.895000  2.332685  0.011880  0.027170  ...  28897.090
# 2  28896.43  28896.016667  2.329443  0.017063  0.022073  ...  28897.090
# 3  28896.44  28896.120000  2.536955  0.019655  0.019525  ...  28897.090
# 4  28896.59  28896.332000  2.978868  0.032854  0.119532  ...  28897.522
#
#             ap2       ap3           ap4           ap5       as1       as2  \
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0           bp1           bp2           bp3           bp4  \
# count   36.000000     36.000000     36.000000     36.000000     36.000000
# mean    17.500000  28897.503932  28897.453247  28897.070765  28896.735146
# std     10.535654      0.412958      0.416029      0.252512      0.232395
# min      0.000000  28896.689000  28896.646333  28896.452333  28896.219333
# 25%      8.750000  28897.102250  28897.056417  28896.907069  28896.534333
# 50%     17.500000  28897.541911  28897.511902  28897.169411  28896.847321
# 75%     26.250000  28897.800833  28897.735500  28897.253094  28896.917463
# max     35.000000  28898.280000  28898.217778  28897.413333  28897.009286
#
#                 bp5        bs1        bs2        bs3        bs4  ...  \
# count     36.000000  36.000000  36.000000  36.000000  36.000000  ...
# mean   28896.508281   2.173123   0.150408   0.220614   0.191742  ...
# std        0.309212   0.342516   0.098836   0.097209   0.080566  ...
# ...

# %%
df['bp1'].astype(int)
# Out:
# 0     28897
# 1     28897
# 2     28897
# 3     28897
# 4     28897
# 5     28897
# 6     28898
# 7     28898
# 8     28898
# 9     28898
# 10    28898
# 11    28897
# 12    28897
# 13    28897
# 14    28897
# 15    28897
# 16    28897
# 17    28897
# 18    28897
# 19    28897
# 20    28897
# 21    28897
# 22    28897
# 23    28897
# 24    28897
# 25    28897
# 26    28897
# 27    28897
# 28    28897
# 29    28897
# 30    28897
# 31    28897
# 32    28896
# 33    28896
# 34    28896
# 35    28896
# Name: bp1, dtype: int64
