# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/Users/marcostellez/code/abefarkas/Thalassa_Regime_Classifier/raw_data/BTCUSDT_S_DEPTH_20220519.csv')

# %%
data
# Out:
#          symbol             ts  last_update_id      bp1    bs1      bp2  \
# 0       BTCUSDT  1652918400006   1519899788740  28700.6  0.155  28699.1
# 1       BTCUSDT  1652918400385   1519899930450  28700.6  0.046  28699.1
# 2       BTCUSDT  1652918400707   1519900081311  28700.6  0.046  28699.1
# 3       BTCUSDT  1652918401133   1519900269449  28700.6  0.046  28699.1
# 4       BTCUSDT  1652918401559   1519900452837  28700.6  0.046  28699.1
# ...         ...            ...             ...      ...    ...      ...
# 149485  BTCUSDT  1653004797460   1523341606366  30320.1  0.634  30320.0
# 149486  BTCUSDT  1653004798043   1523341646731  30320.1  0.363  30320.0
# 149487  BTCUSDT  1653004798569   1523341676332  30319.9  0.102  30319.5
# 149488  BTCUSDT  1653004799141   1523341719651  30319.9  0.578  30319.5
# 149489  BTCUSDT  1653004799658   1523341762387  30319.9  1.444  30319.5
#
#           bs2      bp3    bs3      bp4  ...     ap16   as16     ap17   as17  \
# ...

# %%
data['spread'] = ((data['ap1']/data['bp1']) - 1)

# %%
data.spread.describe()
# Out:
# count    149490.000000
# mean          0.000005
# std           0.000012
# min           0.000003
# 25%           0.000003
# 50%           0.000003
# 75%           0.000003
# max           0.001860
# Name: spread, dtype: float64

# %%
data['ap1']
# Out:
# 0         28700.7
# 1         28700.7
# 2         28700.7
# 3         28700.7
# 4         28700.7
#            ...
# 149485    30320.2
# 149486    30320.2
# 149487    30320.0
# 149488    30320.0
# 149489    30320.0
# Name: ap1, Length: 149490, dtype: float64

# %%
data['bp1']
# Out:
# 0         28700.6
# 1         28700.6
# 2         28700.6
# 3         28700.6
# 4         28700.6
#            ...
# 149485    30320.1
# 149486    30320.1
# 149487    30319.9
# 149488    30319.9
# 149489    30319.9
# Name: bp1, Length: 149490, dtype: float64

# %%
data.tail()
# Out:
#          symbol             ts  last_update_id      bp1    bs1      bp2  \
# 149485  BTCUSDT  1653004797460   1523341606366  30320.1  0.634  30320.0
# 149486  BTCUSDT  1653004798043   1523341646731  30320.1  0.363  30320.0
# 149487  BTCUSDT  1653004798569   1523341676332  30319.9  0.102  30319.5
# 149488  BTCUSDT  1653004799141   1523341719651  30319.9  0.578  30319.5
# 149489  BTCUSDT  1653004799658   1523341762387  30319.9  1.444  30319.5
#
#           bs2      bp3    bs3      bp4  ...   as16     ap17   as17     ap18  \
# 149485  0.015  30319.9  0.114  30319.5  ...  0.008  30323.3  0.976  30323.9
# 149486  0.015  30319.9  0.114  30319.5  ...  0.976  30324.0  0.183  30324.1
# 149487  0.486  30319.4  2.133  30318.9  ...  2.392  30322.9  0.017  30323.0
# 149488  0.561  30319.4  2.133  30318.9  ...  0.616  30322.6  2.392  30322.9
# 149489  0.486  30319.4  4.133  30318.9  ...  0.326  30323.5  0.815  30323.9
#
#          as18     ap19   as19     ap20   as20    spread
# ...
